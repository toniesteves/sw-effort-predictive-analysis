# %% [markdown]
# https://www.researchgate.net/publication/260007339_Potential_and_Limitations_of_the_ISBSG_Dataset_in_Enhancing_Software_Engineering_Research_A_Mapping_Review

# %%
from scipy.io import arff
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Formatação mais bonita para os notebooks
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,5)

# %%
df_albrecht = pd.read_csv('../Datasets/04.isbsg10.csv')
df_albrecht.head()
df_albrecht.iloc[:,0:20]
# Out:
#     id     ID Data_Quality UFP  Year                       IS  \
# 0    1  10592            B   B  2010            Manufacturing
# 1    2  11245            B   B  2010            Manufacturing
# 2    3  11623            B   B  2010            Manufacturing
# 3    4  14319            B   B  2010                  Banking
# 4    5  14653            B   B  2010            Manufacturing
# 5    6  14979            B   B  2010            Manufacturing
# 6    7  15002            A   A  2010                Utilities
# 7    8  15011            B   B  2010         Service Industry
# 8    9  15264            B   B  2010            Manufacturing
# 9   10  17548            B   B  2010    Medical & Health Care
# 10  11  20119            B   B  2010            Manufacturing
# 11  12  20671            B   B  2010            Manufacturing
# 12  13  21017            B   B  2010            Manufacturing
# 13  14  22347            A   A  2010         Service Industry
# ...

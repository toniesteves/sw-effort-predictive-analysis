# %%
from scipy.io import arff
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Formatação mais bonita para os notebooks
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,5)

# %%
df_albrecht = pd.read_csv('../Datasets/04.isbsg10.csv')
df_albrecht.head()
# Out:
#    id     ID Data_Quality UFP  Year             IS             OT  \
# 0   1  10592            B   B  2010  Manufacturing  Manufacturing
# 1   2  11245            B   B  2010  Manufacturing  Manufacturing
# 2   3  11623            B   B  2010  Manufacturing  Manufacturing
# 3   4  14319            B   B  2010        Banking        Banking
# 4   5  14653            B   B  2010  Manufacturing  Manufacturing
#
#                      AG                               AT               DT  \
# 0  Business Application            Track test management  New Development
# 1  Business Application       Part management in factory  New Development
# 2  Business Application  After sales Parts documentation  New Development
# 3  Business Application              Auditing Management  New Development
# 4  Business Application              Parts documentation  New Development
#
#       ...     MAJ_T_Defects X_T_Defects TOT_T_Defects MIN_I_Defects  \
# 0     ...                 ?           ?             ?             ?
# 1     ...                 ?           ?             ?             ?
# 2     ...                 ?           ?           110             ?
# 3     ...                 ?           ?             ?             ?
# 4     ...                 ?           ?             ?             ?
#
#   MAJ_I_Defects X_I_Defects TOT_I_Defects Unnamed: 95 Unnamed: 96 Unnamed: 97
# 0             ?           ?             ?         NaN         NaN         NaN
# 1             ?           ?             ?         NaN         NaN         NaN
# 2             ?           ?             ?         NaN         NaN         NaN
# 3             ?           ?             ?         NaN         NaN         NaN
# 4             ?           ?             ?         NaN         NaN         NaN
#
# [5 rows x 98 columns]

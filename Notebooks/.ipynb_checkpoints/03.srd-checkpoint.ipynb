# %% [markdown]
# ## Data from a Turkish Software Industry (Donated by Software Research Laboratory- Softlab- Bogazici University, Istanbul, Turkey
#
# #### Software effort data collected in the form of COCOMO II. Consists of data from 12 projects and 5 different software companies in various domains.
#
# https://zenodo.org/record/268433#.WvyY-dMvw1I

# %%
from scipy.io import arff
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Formatação mais bonita para os notebooks
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = (15,5)

# %%
df_srd = pd.read_csv('../Datasets/03.srd.csv')

# You can only do that if the variable is ordinal, i.e. if there is a clear ordering 
# (and yes, then it is probably a good idea). But if it is nominal, i.e. "only a name", 
# you have to use dummy variables, i.e. a set of variables for each possibility using 
# one-hot-encoding to designate the value.

pcap_mapping = {'Very Low':1, 'Low':2, 'Nominal':3, 'High':4, 'Very High':5, 'Extra High':6}
ruse_mapping = {'Very Low':1, 'Low':2, 'Nominal':3, 'High':4, 'Very High':5, 'Extra High':6}
team_mapping = {'Very Low':1, 'Low':2, 'Nominal':3, 'High':4, 'Very High':5, 'Extra High':6}
site_mapping = {'Very Low':1, 'Low':2, 'Nominal':3, 'High':4, 'Very High':5, 'Extra High':6}
prec_mapping = {'Very Low':1, 'Low':2, 'Nominal':3, 'High':4, 'Very High':5, 'Extra High':6}
loc_mapping = {'Very Low':1, 'Low':2, 'Nominal':3, 'High':4, 'Very High':5, 'Extra High':6}


df_srd['PCAP'] = df_srd['PCAP'].map(pcap_mapping)
df_srd['RUSE'] = df_srd['RUSE'].map(ruse_mapping)
df_srd['TEAM'] = df_srd['TEAM'].map(team_mapping)
df_srd['SITE'] = df_srd['SITE'].map(site_mapping)
df_srd['PREC'] = df_srd['PREC'].map(prec_mapping)

# df_srd.info()
# df_srd.isnull().values.any()
df_srd.head()
# Out:
#    id  ProjectID  PREC     FLEX  RESL  TEAM      PMAT     RELY       DATA  \
# 0   1          1     5  Nominal   Low     4  Very Low  Nominal    Nominal
# 1   2          2     5  Nominal   Low     5  Very Low     High    Nominal
# 2   3          3     6  Nominal   Low     4  Very Low     High  Very High
# 3   4          4     6     High  High     4   Nominal     High       High
# 4   5          5     3  Nominal   Low     4   Nominal      Low    Nominal
#
#         CPLX  ...    PCAP       PCON       AEXP       PEXP       LTEX  \
# 0        Low  ...       5  Very High  Very High       High       High
# 1        Low  ...       4  Very High  Very High  Very High  Very High
# 2        Low  ...       4  Very High  Very High  Very High  Very High
# 3  Very High  ...       4   Very Low       High  Very High       High
# 4  Very High  ...       4       High    Nominal    Nominal    Nominal
#
#       TOOL  SITE     SCED    LOC ACTUAL
# 0     High     2  Nominal   3000    1.2
# 1     High     1     High   2000    2.0
# 2     High     1     High   4250    4.5
# 3  Nominal     4     High  10000    3.0
# 4  Nominal     4      Low  15000    4.0
#
# [5 rows x 26 columns]

# %%
def print_r2(dependents_var_list, independent_var):
    model = LinearRegression()
    for x in dependents_var_list:
        reg.fit(np.reshape(np.array(df_srd[x]), (len(df_srd[x]), 1)), independent_var) 
        print("R-Squared coefficient of '{}' : {}".format(x,reg.score(np.reshape(np.array(df_srd[x]), (len(df_srd[x]), 1)),independent_var)))


effort = np.reshape(np.array(df_srd['ACTUAL']), (len(df_srd['ACTUAL']), 1)) 
print_r2(['PCAP','RUSE','TEAM','SITE','PREC','LOC'], effort)
# Out:
# R-Squared coefficient of 'PCAP' : 0.028615101623120087
# R-Squared coefficient of 'RUSE' : 0.009404510537974087
# R-Squared coefficient of 'TEAM' : 4.626382595906975e-07
# R-Squared coefficient of 'SITE' : 0.16363119304250606
# R-Squared coefficient of 'PREC' : 0.06734085689055347
# R-Squared coefficient of 'LOC' : 0.6105513546493999

# %% [markdown]
# ### Graphs

# %%
def show_corr(columnName, xlabel, ylabel):
    model = LinearRegression()
    column = df_srd[columnName].values.reshape(-1,1)
    model.fit(column, df_srd['ACTUAL'])
    predictions =  model.predict(column)
    plt.plot(column, predictions, color='red', linewidth=1)
    plt.scatter(column, df_srd['ACTUAL'], alpha=0.4, c=df_srd['ACTUAL'])
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.show()
    
show_corr('PCAP',"Programmer Capability",'Effort')
show_corr('RUSE',"Required Reusability",'Effort')
show_corr('TEAM',"Team Cohesion",'Effort')

# %%
show_corr('SITE',"Multisite Development",'Effort')
show_corr('PREC',"Precedentedness",'Effort')
show_corr('LOC',"Lines of Code",'Effort')
